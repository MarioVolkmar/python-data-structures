# %%
## Crear e imprimir una lista

nombres = ["Mario", "Ana", "Luis", "Sofia", "Carlos"]

print (nombres)

for n in nombres:
    print(n)
# Out:
# ['Mario', 'Ana', 'Luis', 'Sofia', 'Carlos']
# Mario
# Ana
# Luis
# Sofia
# Carlos

# %%
## Acceder a elementos

frutas = ["manzana", "pera", "uva", "mango", "piña"]


print(f"La primera fruta es: {frutas[0]} y la ultima es: {frutas[-1]}")
# Out:
# La primera fruta es: manzana y la ultima es: mango

# %%
## Modificar un elemento

colores = ["rojo", "azul", "verde"]

colores[colores.index("azul")] = "amarillo"

print(colores)
# Out:
# 1

# %%
## Agregar elementos

numeros = [1, 2, 3]

numeros.extend([4,5])

print(numeros)
# Out:
# [1, 2, 3, 4]

# %%
## Eliminar el último elemento

tareas = ["estudiar", "entrenar", "leer", "descansar"]

print(f"La tarea eliminada fue: {tareas.pop()} y la lista de tareas actual quedo como: {tareas}")
# Out:
# La tarea eliminada fue: descansar y la lista de tareas actual quedo como ['estudiar', 'entrenar', 'leer']

# %%
## Eliminar un elemento específico

lenguajes = ["Python", "Java", "C++", "JavaScript"]

lenguajes.remove("Java")

print(lenguajes)
# Out:
# ['Python', 'C++', 'JavaScript']

# %%
## Verificar si un elemento existe

usuarios = ["mario", "ana", "luis"]
usuario_buscado = "mariO"

print("Usuario encontrado") if usuario_buscado in usuarios else print("Usuario no encontrado")

for u in usuarios:
    if u.lower() == usuario_buscado.lower():
        print("Usuario encontrado")
        break
else:
    print("Usuario no encontrado")
# Out:
# Usuario no encontrado
# Usuario encontrado

# %%
## Recorrer una lista

productos = ["pan", "leche", "huevos", "arroz"]

mensaje = ""

for p in productos:
    if  p == productos[-1]:
        mensaje += p 
    else:
        mensaje += p + ", "

print(f"La lista de productos es {mensaje}")
# Out:
# La lista de productos es pan, leche, huevos, arroz

# %%
## Contar elementos manualmente

animales = ["perro", "gato", "conejo", "perro", "loro"]
longitud = 0

for a in animales:
    longitud += 1

print(f"La cantidad de animales es de {longitud}")
# Out:
# La cantidad de animales es de 5

# %%
## Contar cuántas veces aparece un elemento

animales = ["perro", "gato", "conejo", "perro", "loro", "perro"]

n = 0

for a in animales:
    if a.lower() == "perro":
        n += 1

print(f"La cantidad de veces que aparace perro es de {n} veces")
# Out:
# La cantidad de veces que aparace perro es de 3 veces

# %%
## Sumar números de una lista

numeros = [10, 20, 30, 40, 50]

suma = sum(numeros)

suma2 = 0

for n in numeros:
    suma2 += n

print(suma,suma2)
# Out:
# 150 150

# %%
## Promedio de una lista

notas = [4.0, 3.5, 5.0, 2.8, 4.2]

prom = sum(notas) / len(notas)

suma = 0

for n in notas:
    suma += n

promedio = suma / len(notas)

print(prom, promedio)
# Out:
# 3.9 3.9

# %%
## Encontrar el mayor número 

numeros = [15, 8, 22, 3, 19]

maxi = max(numeros)

maximo = numeros[0]

for n in numeros:
    if n > maximo:
        maximo = n

print(maximo, maxi)
# Out:
# 22 22

# %%
## Encontrar el menor número

numeros = [15, 8, 22, 3, 19]

meno = min(numeros)

menor = numeros[0]

for n in numeros:
    if n < menor:
        menor = n

print(menor, meno)
# Out:
# 3 3

# %%
## Separar números pares

numeros = [1, 2, 3, 4, 5, 6, 7, 8]
pares = []

for n in numeros:
    if n % 2 == 0:
        pares.append(n)

print(pares)
# Out:
# [2, 4, 6, 8]

# %%
## Separar positivos, negativos y ceros

numeros = [3, -1, 0, 7, -5, 0, 9, -2]
positivos = []
negativos = []
ceros = []

for n in numeros:
    if n == 0:
        ceros.append(n)
    if n > 0:
        positivos.append(n)
    else:
        negativos.append(n)

print(positivos, negativos, ceros)
# Out:
# [3, 7, 9] [-1, 0, -5, 0, -2] [0, 0]

# %%
## Crear una nueva lista con valores duplicados

numeros = [1, 2, 3, 4, 5]

dobles = []

for n in numeros:
    dobles.append(n*2)

print(dobles)
# Out:
# [2, 4, 6, 8, 10]

# %%
## Filtrar palabras largas

palabras = ["sol", "computador", "python", "backend", "ia"]

palabras_largas = []

for p in palabras:
    if len(p) > 5:
        palabras_largas.append(p)

print (palabras_largas)
# Out:
# ['computador', 'python', 'backend']

# %%
## Lista de compras con menú

compras = []

while True:
    solicitud = input("'1' Agregar producto - '2' Ver producto - '3' Eliminar producto - '4' Salir ")
    if solicitud == "1":
        compra = input("Nombre producto")
        compras.append(compra)
    elif solicitud == "2":
        print(compras)
    elif solicitud == "3":
        if len(compras) > 0:
            compras.pop()
    elif solicitud == "4":
        break
    else:
        print("Ingreso invalido")
# Out:
# ['papa']
# Ingreso invalido
# ['papa', 'lechuga']
# ['papa']

# %%
## Sistema simple de notas

notas = []

while True:
    nota = input("Ingrese una nota de 0 a 5 o salir")
    if nota.lower() == "salir":
        break
    elif 0 <= float(nota) <= 5:
        notas.append(float(nota))
    else:
        print("Nota Invalida")

print(f"Notas : {notas} \nMayor: {max(notas)} \nMenor: {min(notas)} \nPromedio: {sum(notas) / len(notas)}")
# Out:
# Nota Invalida
# Notas : [5.0, 2.0]
# Mayor: 5.0
# Menor: 2.0
# Promedio: 3.5
